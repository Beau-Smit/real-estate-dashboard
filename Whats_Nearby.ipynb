# %%
import pandas as pd
import os
import folium
import EDA.map_functions as maps

# %%
LAT, LON = (41.87476398199688, -87.70960572884961)

# %%
ROOT = "C:/Users/Beau/Documents/GitHub/RealEstate"
CLEANED = os.path.join(ROOT, "data", "processed")

# %%
df_grocery = pd.read_pickle(os.path.join(CLEANED, "Grocery.pkl"))
df_L = pd.read_pickle(os.path.join(CLEANED, "L_Stations.pkl"))
df_metra = pd.read_pickle(os.path.join(CLEANED, "Metra_Stations.pkl"))
df_divvy = pd.read_pickle(os.path.join(CLEANED, "Divvy_Stations.pkl"))
df_mural = pd.read_pickle(os.path.join(CLEANED, "Murals.pkl"))
df_park_art = pd.read_pickle(os.path.join(CLEANED, "Park_Art.pkl"))
# df_license = pd.read_pickle(os.path.join(CLEANED, "Business_Licenses_Current.pkl"))
# TODO: idea - get alcohol licenses
# TODO: banks?

# %%
def place_markers(df, label_col, color, icon):

    for idx, row in df.iterrows():
        maps.add_map_marker(m, lat=row['LATITUDE'], lon=row['LONGITUDE'], name=row[label_col], color=color, icon=icon)
        # maps.add_map_circle(row.Latitude, row.Longitude)

# %%
# icon list: https://getbootstrap.com/docs/3.3/components/
# color choices:: ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 
# 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

# Create a Map instance for Chicago
m = folium.Map(location=[LAT, LON], zoom_start=16)

# add marker for the property of interest
maps.add_map_marker(m, lat=LAT, lon=LON, name="property", color='black', icon='home')

place_markers(df_grocery, label_col='STORE NAME', color='green', icon='shopping-cart')
place_markers(df_L, label_col='STATION_NAME', color='darkblue', icon='random')
place_markers(df_metra, label_col='STATION_NAME', color='lightblue', icon='retweet')
place_markers(df_divvy, label_col='STATION NAME', color='blue', icon='road')
place_markers(df_mural, label_col='ARTWORK TITLE', color='pink', icon='picture')
place_markers(df_park_art, label_col='ART', color='red', icon='tree-conifer')
# place_markers(df_license, label_col=, color=, icon=)

# Change the map style
# m.add_tile_layer(tiles='Stamen Toner', name='Stamen Toner')

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

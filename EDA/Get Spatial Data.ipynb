# %%
import os
import pandas as pd
import numpy as np
import requests
import yaml
import re
from utils import get_SODA_data
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon

pd.set_option("mode.chained_assignment", None)

# %%
ROOT = "C:/Users/Beau/Documents/GitHub/RealEstate"
CLEANED = os.path.join(ROOT, "data", "processed")
SHAPE_FILES = os.path.join(ROOT, "data", "raw", "shape_files")

# %%
df_EV_chargers = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/iq3c-68ew.json",
    custom_filter="&city=Chicago",
)

df_EV_chargers["label"] = df_EV_chargers["ev_network"]
df_EV_chargers.head()
# Out:
#             ev_network                               station_name  \
# 0        Blink Network  University of Illinois - 915 S Paulina St
# 1                  NaN                                MCC Chicago
# 2  ChargePoint Network                    900 SELF PARK 8TH FLOOR
# 3                Tesla                Target - Tesla Supercharger
# 4        Non-Networked                 St John's Episcopal Church
#
#   fuel_type_code                                           location  \
# 0           ELEC  {'latitude': '41.864575', 'needs_recoding': Fa...
# 1            E85  {'latitude': '41.876579', 'needs_recoding': Fa...
# 2           ELEC  {'latitude': '40.162314', 'needs_recoding': Fa...
# 3           ELEC  {'latitude': '41.92780291', 'needs_recoding': ...
# 4           ELEC  {'latitude': '41.9515574', 'needs_recoding': F...
#
#   station_phone                                 ev_network_web     city  \
# 0  888-998-2546       {'url': 'http://www.blinkcharging.com/'}  Chicago
# 1           NaN                                            NaN  Chicago
# 2  888-758-4389         {'url': 'http://www.chargepoint.com/'}  Chicago
# 3  877-798-3752  {'url': 'https://www.tesla.com/supercharger'}  Chicago
# 4  650-200-3488                                            NaN  Chicago
#
#   intersection_directions status_code state  ... owner_type_code  \
# 0             1st Floor||           E    IL  ...             NaN
# 1                  Garage           E    IL  ...              FG
# 2                     NaN           E    IL  ...             NaN
# 3                     NaN           E    IL  ...               P
# 4                     NaN           E    IL  ...               P
#
#   ev_dc_fast_count        cards_accepted expected_date ev_level1_evse_num  \
# 0              NaN                   NaN           NaN                NaN
# 1              NaN                   NaN           NaN                NaN
# 2              NaN                   NaN           NaN                NaN
# 3               12                   NaN           NaN                NaN
# 4              NaN  A CREDIT D Debit M V           NaN                NaN
#
#   lpg_primary ng_psi ng_fill_type_code ng_vehicle_class                label
# 0         NaN    NaN               NaN              NaN        Blink Network
# 1         NaN    NaN               NaN              NaN                  NaN
# 2         NaN    NaN               NaN              NaN  ChargePoint Network
# 3         NaN    NaN               NaN              NaN                Tesla
# 4         NaN    NaN               NaN              NaN        Non-Networked
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Farmer's Markets

# %%
df_farmers_market = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/atzs-u7pv.json"
)

df_farmers_market["label"] = df_farmers_market["day"]
df_farmers_market.head()
# Out:
#   :@computed_region_43wa_7qmu link_accepted                        location  \
# 0                          16            NO                       Edgewater
# 1                           9           YES           Homegrown Bronzeville
# 2                          14           YES  Covenant Bank - North Lawndale
# 3                          50            NO    Jefferson Park Sunday Market
# 4                          48           YES                      Bridgeport
#
#           type :@computed_region_rpca_8um6     latitude  \
# 0  Independent                          14   41.9918227
# 1  Independent                          10  41.80197062
# 2  Independent                          30  41.86780306
# 3  Independent                          48  41.96800571
# 4       Weekly                          40  41.83081542
#
#   :@computed_region_awaf_s7ux start_time end_time     longitude  \
# 0                          40    8:00 AM  1:00 PM  -87.66032349
# 1                          12    9:00 AM  1:00 PM  -87.61768784
# 2                          36    8:00 AM  1:00 PM  -87.71044099
# 3                          20   10:00 AM  2:00 PM  -87.75834697
# 4                          26    7:00 AM  1:00 PM  -87.64123528
#
#   :@computed_region_bdys_3d7i :@computed_region_6mkv_f3dw  \
# 0                         536                        4451
# 1                         218                       21192
# 2                          98                       21572
# 3                         129                       21869
# 4                         149                       14924
#
#                   end_date         intersection               start_date  \
# 0  2012-10-13T00:00:00.000   Broadway & Norwood  2012-06-09T00:00:00.000
# 1  2012-10-28T00:00:00.000        343 E 51st St  2012-06-10T00:00:00.000
# 2  2012-10-10T00:00:00.000     1111 S Homan Ave  2012-06-13T00:00:00.000
# 3  2012-10-21T00:00:00.000  5216 W Lawrence Ave  2012-06-24T00:00:00.000
# 4  2012-10-06T00:00:00.000       35th & Wallace  2012-06-16T00:00:00.000
#
#          day :@computed_region_vrxf_vc4k  \
# 0   Saturday                          76
# 1     Sunday                           7
# 2  Wednesday                          30
# 3     Sunday                          11
# 4   Saturday                          58
#
#                                                  map  \
# 0  {'latitude': '41.9918227', 'needs_recoding': F...
# 1  {'latitude': '41.80197062', 'needs_recoding': ...
# 2  {'latitude': '41.86780306', 'needs_recoding': ...
# 3  {'latitude': '41.96800571', 'needs_recoding': ...
# 4  {'latitude': '41.83081542', 'needs_recoding': ...
#
#                                           website      label
# 0                                             NaN   Saturday
# 1        {'url': 'http://www.greenyouthfarm.com'}     Sunday
# 2                                             NaN  Wednesday
# 3               {'url': 'http://www.jpna.net/FM'}     Sunday
# 4  {'url': 'http://www.chicagofarmersmarkets.us'}   Saturday

# %% [markdown]
# ## Divvy Stations

# %%
df_divvy = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/bbyy-e7gq.json"
)

df_divvy["label"] = df_divvy["station_name"]
df_divvy.head()
# Out:
#   id            station_name total_docks docks_in_service          status  \
# 0  2     Buckingham Fountain          39               39  Not In Service
# 1  3          Shedd Aquarium          55               55      In Service
# 2  4          Burnham Harbor          23               23      In Service
# 3  5  State St & Harrison St          23               23      In Service
# 4  6          Dusable Harbor          39               39      In Service
#
#        latitude      longitude  \
# 0     41.876423     -87.620339
# 1  41.867225957   -87.61535539
# 2  41.857411787  -87.613791525
# 3     41.874053     -87.627716
# 4     41.886976     -87.612813
#
#                                             location  \
# 0  {'latitude': '41.876423', 'longitude': '-87.62...
# 1  {'latitude': '41.86722595682', 'longitude': '-...
# 2  {'latitude': '41.85741178707404', 'longitude':...
# 3  {'latitude': '41.874053', 'longitude': '-87.62...
# 4  {'latitude': '41.886976', 'longitude': '-87.61...
#
#   :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 0                          22                       14913
# 1                          48                       14913
# 2                          48                       21194
# 3                          48                       14913
# 4                          22                       21182
#
#   :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 0                          38                         367
# 1                          34                         374
# 2                          34                         374
# 3                          38                          12
# 4                          38                         159
#
#   :@computed_region_43wa_7qmu                   label
# 0                          36     Buckingham Fountain
# 1                          10          Shedd Aquarium
# 2                          10          Burnham Harbor
# 3                          10  State St & Harrison St
# 4                          36          Dusable Harbor

# %% [markdown]
# ## L Stations

# %%
df_L = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/8pix-ypme.json"
)

df_L["label"] = df_L["station_descriptive_name"]
df_L.head()
# Out:
#   stop_id direction_id                        stop_name          station_name  \
# 0   30162            W         18th (54th/Cermak-bound)                  18th
# 1   30161            E                18th (Loop-bound)                  18th
# 2   30022            N         35th/Archer (Loop-bound)           35th/Archer
# 3   30023            S       35th/Archer (Midway-bound)           35th/Archer
# 4   30214            S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#             station_descriptive_name map_id   ada    red   blue      g  ...  \
# 0                   18th (Pink Line)  40830  True  False  False  False  ...
# 1                   18th (Pink Line)  40830  True  False  False  False  ...
# 2          35th/Archer (Orange Line)  40120  True  False  False  False  ...
# 3          35th/Archer (Orange Line)  40120  True  False  False  False  ...
# 4  35th-Bronzeville-IIT (Green Line)  41120  True  False  False   True  ...
#
#        y    pnk      o                                           location  \
# 0  False   True  False  {'latitude': '41.857908', 'longitude': '-87.66...
# 1  False   True  False  {'latitude': '41.857908', 'longitude': '-87.66...
# 2  False  False   True  {'latitude': '41.829353', 'longitude': '-87.68...
# 3  False  False   True  {'latitude': '41.829353', 'longitude': '-87.68...
# 4  False  False  False  {'latitude': '41.831677', 'longitude': '-87.62...
#
#    :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# 0                            8                        14920
# 1                            8                        14920
# 2                           26                        14924
# 3                           26                        14924
# 4                           12                        21194
#
#   :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 0                          33                         343
# 1                          33                         343
# 2                          56                         719
# 3                          56                         719
# 4                           1                          25
#
#   :@computed_region_43wa_7qmu                              label
# 0                          26                   18th (Pink Line)
# 1                          26                   18th (Pink Line)
# 2                           1          35th/Archer (Orange Line)
# 3                           1          35th/Archer (Orange Line)
# 4                           9  35th-Bronzeville-IIT (Green Line)
#
# [5 rows x 23 columns]

# %%
# extract latitude and longitude
df_L["latitude"] = df_L.location.apply(lambda x: x["latitude"]).astype(float)
df_L["longitude"] = df_L.location.apply(lambda x: x["longitude"]).astype(float)

# %% [markdown]
# ## Business Licenses

# %%
df_licenses = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/r5kz-chrr.json"
)

# remove records with no coordinate data
df_licenses = df_licenses.loc[
    df_licenses.latitude.notnull() & df_licenses.longitude.notnull()
].reset_index(drop=True)

df_licenses["label"] = df_licenses["doing_business_as_name"]
df_licenses.head()
# Out:
#                  id license_id account_number site_number  \
# 0  2617269-20220916    2857496           1611           5
# 1  2652692-20201217    2652692         456833           1
# 2  2647849-20200916    2739788          64603           7
# 3  1579838-20220616    2842924         289144           1
# 4  2027540-20220616    2841687          10726           5
#
#                 legal_name    doing_business_as_name  \
# 0              TTX COMPANY               TTX COMPANY
# 1      JYM INVESTMENTS LLC                   WINGMAN
# 2  LEOPARDO COMPANIES INC.    Leopardo Companies Inc
# 3    1021 MONTROSE, L.L.C.                 Driftwood
# 4    GRAHAM ENTERPRISE INC  Rock N Roll BP (GEI-157)
#
#                         address     city state zip_code  ...      longitude  \
# 0            4016 S ASHLAND AVE  CHICAGO    IL    60609  ...  -87.665396822
# 1          2321 W HOWARD ST 1ST  CHICAGO    IL    60645  ...  -87.688628188
# 2  210 N CARPENTER ST 3RD FLOOR  CHICAGO    IL    60607  ...  -87.653461783
# 3           1021 W MONTROSE AVE  CHICAGO    IL    60613  ...  -87.655649945
# 4         631-647 N LA SALLE DR  CHICAGO    IL    60654  ...  -87.632493012
#
#                                             location  \
# 0  {'latitude': '41.82028493557808', 'longitude':...
# 1  {'latitude': '42.019413270594214', 'longitude'...
# 2  {'latitude': '41.88594495760403', 'longitude':...
# 3  {'latitude': '41.961655308981946', 'longitude'...
# 4  {'latitude': '41.89325119846543', 'longitude':...
#
#   :@computed_region_vrxf_vc4k :@computed_region_awaf_s7ux  \
# 0                          59                          29
# 1                          20                           3
# 2                          29                          41
# 3                          31                          37
# 4                          37                          22
#
#   :@computed_region_6mkv_f3dw :@computed_region_bdys_3d7i  \
# 0                       14924                         706
# 1                       22528                         341
# 2                       14917                          63
# 3                       21186                         577
# 4                        4446                         670
#
#   :@computed_region_43wa_7qmu license_status_change_date  ssa  \
# 0                           1                        NaN  NaN
# 1                           5    2022-08-08T00:00:00.000  NaN
# 2                          46    2022-08-08T00:00:00.000  NaN
# 3                          39                        NaN   34
# 4                          36                        NaN  NaN
#
#                       label
# 0               TTX COMPANY
# 1                   WINGMAN
# 2    Leopardo Companies Inc
# 3                 Driftwood
# 4  Rock N Roll BP (GEI-157)
#
# [5 rows x 40 columns]

# %%
df_licenses.latitude = df_licenses.latitude.astype(float)
df_licenses.longitude = df_licenses.longitude.astype(float)

# %% [markdown]
# ## Current Business Licenses

# %%
df_current_licenses = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/uupf-x98q.json"
)

# remove records with no coordinate data
df_current_licenses = df_current_licenses.loc[
    df_current_licenses.latitude.notnull() & df_current_licenses.longitude.notnull()
]

df_current_licenses["label"] = df_current_licenses["license_description"]
df_current_licenses.head()
# Out:
#           license_description zip_code license_id  \
# 0  Regulated Business License    60620    2856938
# 1         Mobile Food License    60608    2877055
# 2  Regulated Business License    60657    2909383
# 3    Limited Business License    60609    2911368
# 5   Retail Food Establishment    60643    2908956
#
#                                             location              date_issued  \
# 0  {'latitude': '41.748245609196715', 'human_addr...  2022-08-09T00:00:00.000
# 1  {'latitude': '41.85045102427', 'human_address'...  2022-10-27T00:00:00.000
# 2  {'latitude': '41.944108848555665', 'human_addr...  2023-05-17T00:00:00.000
# 3  {'latitude': '41.81944142629576', 'human_addre...  2023-05-24T00:00:00.000
# 5  {'latitude': '41.69224436617783', 'human_addre...  2023-05-24T00:00:00.000
#
#       city ward_precinct                   address license_status  \
# 0  CHICAGO         18-18        8001 S WESTERN AVE            AAI
# 1  CHICAGO          25-2          2300 S THROOP ST            AAI
# 2  CHICAGO         44-38  3416 N SHEFFIELD AVE 1ST            AAI
# 3  CHICAGO         12-19        4100 S ASHLAND AVE            AAI
# 5  CHICAGO         21-43        805 W 111TH ST 1ST            AAI
#
#   conditional_approval  ... license_approved_for_issuance  \
# 0                    N  ...       2022-08-08T00:00:00.000
# 1                    N  ...       2022-10-27T00:00:00.000
# 2                    N  ...       2023-05-16T00:00:00.000
# 3                    N  ...       2023-05-23T00:00:00.000
# 5                    N  ...       2023-05-23T00:00:00.000
#
#            expiration_date account_number site_number license_code  \
# 0  2025-12-15T00:00:00.000         378455           1         4404
# 1  2023-09-15T00:00:00.000         378104           7         4405
# 2  2025-07-15T00:00:00.000         377221           2         4404
# 3  2025-07-15T00:00:00.000         476495           2         1010
# 5  2025-07-15T00:00:00.000         338898           1         1006
#
#                                           legal_name                id  ssa  \
# 0  FOREST EDGE HEALTHCARE & REHABILITATION CENTER...  2283660-20231216  NaN
# 1                                       PERK UP INC.  2689771-20230916  NaN
# 2                                  REFLEXION SPA LLC  2698731-20230716   17
# 3            AMERICAN EXPORT & GENERAL SERVICES INC.  2867883-20230716   10
# 5                 TONY'S STEAK GYROS & LEMONADE INC.  1942358-20230716   45
#
#   application_created_date                       label
# 0                      NaN  Regulated Business License
# 1                      NaN         Mobile Food License
# 2                      NaN  Regulated Business License
# 3                      NaN    Limited Business License
# 5                      NaN   Retail Food Establishment
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Liquor Business Licenses

# %%
df_liquor = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/nrmj-3kcf.json"
)

# remove records with no coordinate data
df_liquor = df_liquor.loc[df_liquor.latitude.notnull() & df_liquor.longitude.notnull()]

df_liquor["label"] = df_liquor["legal_name"]
df_liquor.head()
# Out:
#   zip_code :@computed_region_43wa_7qmu  \
# 0    60647                          41
# 1    60613                          39
# 2    60634                          17
# 3    60639                          45
# 4    60607                          46
#
#                              license_description license_id  \
# 0  Consumption on Premises - Incidental Activity    2806251
# 1                                         Tavern    2842924
# 2  Consumption on Premises - Incidental Activity    2804007
# 3                                  Package Goods    2878957
# 4  Consumption on Premises - Incidental Activity    2880684
#
#                                             location              date_issued  \
# 0  {'latitude': '41.91736812603766', 'human_addre...  2021-08-17T00:00:00.000
# 1  {'latitude': '41.961655308981946', 'human_addr...  2022-05-11T00:00:00.000
# 2  {'latitude': '41.93758152034964', 'human_addre...  2021-10-05T00:00:00.000
# 3  {'latitude': '41.90933896530053', 'human_addre...  2022-12-27T00:00:00.000
# 4  {'latitude': '41.88424444452276', 'human_addre...  2022-12-27T00:00:00.000
#
#       city ward_precinct                 address license_status  ...  \
# 0  CHICAGO         26-20     2833 W ARMITAGE AVE            AAI  ...
# 1  CHICAGO          46-9     1021 W MONTROSE AVE            AAI  ...
# 2  CHICAGO         31-15  3127 N CENTRAL AVE 1ST            AAI  ...
# 3  CHICAGO          37-6      5345 W NORTH AVE 1            AAI  ...
# 4  CHICAGO          27-1   917-923 W RANDOLPH ST            AAI  ...
#
#            expiration_date account_number site_number license_code  \
# 0  2023-10-15T00:00:00.000         397430           1         1475
# 1  2024-06-15T00:00:00.000         289144           1         1470
# 2  2023-10-15T00:00:00.000           3542           1         1475
# 3  2025-01-15T00:00:00.000          11998           1         1474
# 4  2025-01-15T00:00:00.000         393943           1         1475
#
#               legal_name :@computed_region_vrxf_vc4k                id  ssa  \
# 0     WANDERING CHEF LLC                          23  2391388-20211016  NaN
# 1  1021 MONTROSE, L.L.C.                          31  1579838-20220616   34
# 2   CENTRAL GYROS, CORP.                          19    28852-20211016    2
# 3  ABH FOOD & LIQUOR INC                          26    30044-20230116  NaN
# 4       B RESTAURANT LLC                          29  2359724-20230116  NaN
#
#   application_created_date                  label
# 0                      NaN     WANDERING CHEF LLC
# 1                      NaN  1021 MONTROSE, L.L.C.
# 2                      NaN   CENTRAL GYROS, CORP.
# 3                      NaN  ABH FOOD & LIQUOR INC
# 4                      NaN       B RESTAURANT LLC
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Landmarks

# %%
df_landmarks = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/tdab-kixi.json"
)

df_landmarks["label"] = df_landmarks["landmark_name"]
df_landmarks.head()
# Out:
#                                        landmark_name     id  \
# 0            Vassar Swiss Underwear Company Building  L-265
# 1                               Mathilde Eliel House  L- 89
# 2                                 Manhattan Building  L-139
# 3  Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                             Melissa Ann Elam House  L- 88
#
#                               address landmark_designation_date  \
# 0           2543 - 2545 W Diversey Av  2008-07-30T07:00:00.000Z
# 1                     4122 S Ellis Av  1991-10-02T07:00:00.000Z
# 2                   431 S Dearborn St  1978-07-07T07:00:00.000Z
# 3                       100 W 33rd St  2004-05-26T07:00:00.000Z
# 4  4726 S Dr Martin Luther King Jr Dr  1979-03-21T08:00:00.000Z
#
#          latitude        longitude  \
# 0  41.93162660840  -87.69210009570
# 1  41.81925575100  -87.60278799920
# 2  41.87606572340  -87.62896445050
# 3  41.83516141220  -87.62922122350
# 4  41.80852976900  -87.61720439490
#
#                                             location  \
# 0  {'latitude': '41.9316266084', 'longitude': '-8...
# 1  {'latitude': '41.819255751', 'longitude': '-87...
# 2  {'latitude': '41.8760657234', 'longitude': '-8...
# 3  {'latitude': '41.8351614122', 'longitude': '-8...
# 4  {'latitude': '41.808529769', 'longitude': '-87...
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                           1                          23
# 1                          36                           2
# 2                          35                          38
# 3                          40                           1
# 4                          10                           4
#
#   :@computed_region_6mkv_f3dw :@computed_region_bdys_3d7i  \
# 0                       22535                         240
# 1                        4301                         220
# 2                       14913                          92
# 3                       21194                          25
# 4                       21192                         162
#
#   :@computed_region_43wa_7qmu :@computed_region_awaf_s7ux date_built  \
# 0                          40                          24        NaN
# 1                          10                           1       1886
# 2                          10                          48       1891
# 3                           9                          12       1901
# 4                           9                          12       1903
#
#                  architect                                              label
# 0                      NaN            Vassar Swiss Underwear Company Building
# 1         Adler & Sullivan                               Mathilde Eliel House
# 2   William LeBaron Jenney                                 Manhattan Building
# 3  Patton, Fisher & Miller  Machinery Hall at Illinois Institute of Techno...
# 4        Henry L. Newhouse                             Melissa Ann Elam House

# %% [markdown]
# ## Public Park Art

# %%
df_park_art = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/sj6t-9cju.json"
)

df_park_art["label"] = df_park_art["art"]
df_park_art.head()
# Out:
#               park_name park_number                                art  \
# 0  HUMBOLDT (BARON VON)         219                Interpreting Nature
# 1       SENN (NICHOLAS)         227                  The Young Lincoln
# 2     LINCOLN (ABRAHAM)         100          Kwa-Ma-Rolas (Totem Pole)
# 3       ARRIGO (VICTOR)         215  Christopher Columbus and Fountain
# 4     LINCOLN (ABRAHAM)         100                Curve XXII (I Will)
#
#             artist owner        x_coordinate        y_coordinate  \
# 0  Roman Villareal   CPD       1156808.64946  1909066.8679200001
# 1     Charles Keck   CPD  1164734.0056499999       1939563.37418
# 2    Haida Indians   CPD       1172198.75844  1924752.8578699999
# 3    Moses Ezekiel   CPD       1167268.04553        1896559.5281
# 4  Ellsworth Kelly   CPD  1174726.4062699999       1916451.13989
#
#              latitude            longitude  \
# 0  41.906255000000002  -87.699420000000003
# 1  41.989775000000002  -87.669439999999994
# 2  41.948971999999998  -87.642422999999994
# 3  41.871715999999999  -87.661359000000004
# 4           41.926136           -87.633381
#
#                                             location  \
# 0  {'latitude': '41.906255', 'longitude': '-87.69...
# 1  {'latitude': '41.989775', 'longitude': '-87.66...
# 2  {'latitude': '41.948972', 'longitude': '-87.64...
# 3  {'latitude': '41.871716', 'longitude': '-87.66...
# 4  {'latitude': '41.926136', 'longitude': '-87.63...
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                           4                          25
# 1                          14                          76
# 2                          53                          57
# 3                          44                          29
# 4                          16                          68
#
#   :@computed_region_6mkv_f3dw :@computed_region_bdys_3d7i  \
# 0                       22535                         301
# 1                        4451                         539
# 2                        4449                         726
# 3                       14917                         759
# 4                       21190                         101
#
#   :@computed_region_43wa_7qmu :@computed_region_awaf_s7ux  \
# 0                          49                          10
# 1                          16                          40
# 2                          39                          37
# 3                          23                           8
# 4                          34                          51
#
#                                label
# 0                Interpreting Nature
# 1                  The Young Lincoln
# 2          Kwa-Ma-Rolas (Totem Pole)
# 3  Christopher Columbus and Fountain
# 4                Curve XXII (I Will)

# %% [markdown]
# ## Murals

# %%
df_murals = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/we8h-apcf.json"
)

df_murals["label"] = df_murals["artwork_title"]
df_murals.head()
# Out:
#   mural_registration_id                artist_credit  \
# 0                 19001         Kerry James Marshall
# 1                 19043  Rahmaan Statik, Max Sansing
# 2                 19139                Hector Duarte
# 3                 19135           Mirtes Zwierzynski
# 4                 19148                   Ed Paschke
#
#                                 artwork_title     media year_installed  \
# 0                                   Rush More  Painting           2017
# 1                                       Sepia     Paint           2016
# 2                               Honor Boricua       NaN           1993
# 3  Garfield Park Conservatory Alliance Mosaic       NaN           2007
# 4                            Luna Negra, 1998     Paint           2014
#
#                     location_description            street_address    zip  \
# 0  Chicago Cultural Center, West Fa̤ade        78 E Washington St  60602
# 1                                    NaN   2230 S Central Park Ave  60623
# 2                                    NaN      2601 W Evergreen Ave  60622
# 3               N Hamlin Ave and Lake St  N Hamlin Ave and Lake St  60624
# 4          Outside left wall of building        5415 W Higgins Ave  60630
#
#   ward affiliated_or_commissioning  ...     latitude     longitude  \
# 0   42                       DCASE  ...  41.88333428  -87.62505014
# 1   22    Chicago Public Art Group  ...    41.850922    -87.715009
# 2   26    Chicago Public Art Group  ...  41.90560086  -87.69214278
# 3   28    Chicago Public Art Group  ...    41.885114    -87.721068
# 4   45       Ed Paschke Art Center  ...  41.96872306  -87.76207536
#
#                                             location  \
# 0  {'type': 'Point', 'coordinates': [-87.62505014...
# 1  {'type': 'Point', 'coordinates': [-87.715009, ...
# 2  {'type': 'Point', 'coordinates': [-87.69214278...
# 3  {'type': 'Point', 'coordinates': [-87.721068, ...
# 4  {'type': 'Point', 'coordinates': [-87.76207536...
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                          41                          38
# 1                          57                          32
# 2                           4                          25
# 3                          30                          27
# 4                          48                          11
#
#   :@computed_region_6mkv_f3dw :@computed_region_bdys_3d7i  \
# 0                       14310                         580
# 1                       21569                         754
# 2                       21560                         543
# 3                       21572                         658
# 4                       21869                         129
#
#   :@computed_region_43wa_7qmu year_restored  \
# 0                          36           NaN
# 1                          28           NaN
# 2                          49           NaN
# 3                          23           NaN
# 4                          50           NaN
#
#                                         label
# 0                                   Rush More
# 1                                       Sepia
# 2                               Honor Boricua
# 3  Garfield Park Conservatory Alliance Mosaic
# 4                            Luna Negra, 1998
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Grocery Stores

# %%
df_grocery = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/3e26-zek2.json"
)

# remove records with no coordinate data
df_grocery = df_grocery.loc[df_grocery.location.notnull()]

df_grocery["label"] = df_grocery["store_name"]
df_grocery.head()
# Out:
#                store_name                  address         zip new_status  \
# 0            Jewel - Osco             87 W 87th St       60620       OPEN
# 1           Farm on Ogden         3555 W OGDEN AVE       60623       OPEN
# 2            Jewel - Osco       5343 N Broadway St  60640-2311       OPEN
# 3  International Foods NW     4404 W FULLERTON AVE       60639       OPEN
# 4            Jewel - Osco  2520 N Narragansett Ave  60639-1041       OPEN
#
#               last_updated                                           location  \
# 0  2020-06-03T17:00:00.000  {'type': 'Point', 'coordinates': [-87.626243, ...
# 1  2020-06-10T00:00:00.000  {'type': 'Point', 'coordinates': [-87.71437, 4...
# 2  2020-06-03T17:00:00.000  {'type': 'Point', 'coordinates': [-87.659887, ...
# 3  2020-06-10T00:00:00.000  {'type': 'Point', 'coordinates': [-87.737127, ...
# 4  2020-06-03T17:00:00.000  {'type': 'Point', 'coordinates': [-87.785559, ...
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                          59                          40
# 1                          57                          30
# 2                          15                          76
# 3                           2                          21
# 4                           3                          19
#
#   :@computed_region_6mkv_f3dw :@computed_region_bdys_3d7i  \
# 0                       21554                           1
# 1                       21569                         157
# 2                       22616                         160
# 3                       22615                         439
# 4                       22615                         137
#
#   :@computed_region_43wa_7qmu                   label
# 0                          13            Jewel - Osco
# 1                          14           Farm on Ogden
# 2                          16            Jewel - Osco
# 3                          17  International Foods NW
# 4                          44            Jewel - Osco

# %%
# extract latitude and longitude
df_grocery["latitude"] = df_grocery.location.apply(
    lambda x: x["coordinates"][1]
).astype(float)
df_grocery["longitude"] = df_grocery.location.apply(
    lambda x: x["coordinates"][0]
).astype(float)

# %% [markdown]
# ## Hospitals

# %%
df_hospitals = gpd.read_file(os.path.join(SHAPE_FILES, "Hospitals.zip"))
df_hospitals["label"] = df_hospitals["LABEL"]
df_hospitals.head()
# Out:
#      BLDGID            X            Y BLDGNOTES               LABEL  \
# 0   34142.0  1168427.011  1940926.452      None  Kindred- Lakeshore
# 1  262155.0  1171002.449  1916046.010      None          Children's
# 2  533051.0  1175254.006  1862670.662      None          St Bernard
# 3  565454.0  1159091.550  1859131.693      None          Holy Cross
# 4  220136.0  1169801.369  1920306.523      None          IL Masonic
#
#                                    FACILITY     CITY                ADDRESS  \
# 0      Kindred Hospital - Chicago Lakeshore  Chicago       6130 N. Sheridan
# 1              Children's Memorial Hospital  Chicago  2300 Children's Plaza
# 2                       St Bernard Hospital  Chicago     326 W. 64th Street
# 3                       Holy Cross Hospital  Chicago    2701 W. 68th Street
# 4  Advocate Illinois Masonic Medical Center  Chicago      836 W. Wellington
#
#                              COMMONNAME     TYPE1  ...   CA2        USE  \
# 0  Kindred Hospital - Chicago Lakeshore  HOSPITAL  ...  77.0  Hospitals
# 1          Children's Memorial Hospital  HOSPITAL  ...   7.0  Hospitals
# 2                  St. Bernard Hospital  HOSPITAL  ...  68.0  Hospitals
# 3                   Holy Cross Hospital  HOSPITAL  ...  66.0  Hospitals
# 4     Advocate Illinois Masonic Med Ctr  HOSPITAL  ...   6.0  Hospitals
#
#      EDITDATE    ZIP WARD   TRACT AREA_NUMBE     COMMUNITY  \
# 0  2007-08-10  60660   48  030100         77     EDGEWATER
# 1  2007-08-10  60614   43  071200          7  LINCOLN PARK
# 2  2007-08-10  60621   20  680900         68     ENGLEWOOD
# 3  2007-08-10  60629   15  660900         66  CHICAGO LAWN
# 4  2007-08-10  60657   44  063000          6     LAKE VIEW
#
#                           geometry               label
# 0  POINT (1168427.011 1940926.452)  Kindred- Lakeshore
# 1  POINT (1171002.449 1916046.010)          Children's
# 2  POINT (1175254.006 1862670.662)          St Bernard
# 3  POINT (1159091.550 1859131.693)          Holy Cross
# 4  POINT (1169801.369 1920306.523)          IL Masonic
#
# [5 rows x 25 columns]

# %%
df_hospitals["longitude"] = df_hospitals.geometry.to_crs(4326).geometry.x
df_hospitals["latitude"] = df_hospitals.geometry.to_crs(4326).geometry.y

# %% [markdown]
# ## Metra Stations

# %%
df_metra = pd.read_csv(os.path.join(ROOT, "data", "raw", "Metra_Stations.csv"))
df_metra["label"] = df_metra["station_name"]
df_metra.head()
# Out:
#   source    station_name   latitude  longitude           label
# 0  metra   Union Station  41.878683 -87.638892   Union Station
# 1  metra  Western Avenue  41.889180 -87.688161  Western Avenue
# 2  metra           Healy  41.924750 -87.727983           Healy
# 3  metra        Grayland  41.948852 -87.740302        Grayland
# 4  metra         Mayfair  41.960163 -87.746298         Mayfair

# %% [markdown]
# ## Building Permits

# %%
df_permits = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/building-permits.json"
)

# remove records with no coordinate data
df_permits = df_permits.loc[
    df_permits.latitude.notnull() & df_permits.longitude.notnull()
]

df_permits["label"] = df_permits["permit_type"]
df_permits.head()
# Out:
#         id    permit_                     permit_type           review_type  \
# 0  1614287  100072880  PERMIT - RENOVATION/ALTERATION  STANDARD PLAN REVIEW
# 1  1614371  100072936                  PERMIT - SIGNS           SIGN PERMIT
# 2  1641218  100089035                  PERMIT - SIGNS           SIGN PERMIT
# 3  1641219  100089036                  PERMIT - SIGNS           SIGN PERMIT
# 4  1641220  100089037                  PERMIT - SIGNS           SIGN PERMIT
#
#     application_start_date               issue_date processing_time  \
# 0  2005-10-14T00:00:00.000  2006-01-03T00:00:00.000              81
# 1  2005-10-17T00:00:00.000  2006-01-12T00:00:00.000              87
# 2  2006-01-10T00:00:00.000  2006-01-10T00:00:00.000               0
# 3  2006-01-10T00:00:00.000  2006-01-10T00:00:00.000               0
# 4  2006-01-11T00:00:00.000  2006-01-11T00:00:00.000               0
#
#   street_number street_direction  street_name  ... contact_14_name  \
# 0          2728                N   MONTICELLO  ...             NaN
# 1           120                S     LA SALLE  ...             NaN
# 2          4001                W  IRVING PARK  ...             NaN
# 3          4001                W  IRVING PARK  ...             NaN
# 4          4001                W  IRVING PARK  ...             NaN
#
#   contact_14_city contact_14_state contact_14_zipcode contact_15_type  \
# 0             NaN              NaN                NaN             NaN
# 1             NaN              NaN                NaN             NaN
# 2             NaN              NaN                NaN             NaN
# 3             NaN              NaN                NaN             NaN
# 4             NaN              NaN                NaN             NaN
#
#   contact_15_name contact_15_city contact_15_state contact_15_zipcode  \
# 0             NaN             NaN              NaN                NaN
# 1             NaN             NaN              NaN                NaN
# 2             NaN             NaN              NaN                NaN
# 3             NaN             NaN              NaN                NaN
# 4             NaN             NaN              NaN                NaN
#
#                             label
# 0  PERMIT - RENOVATION/ALTERATION
# 1                  PERMIT - SIGNS
# 2                  PERMIT - SIGNS
# 3                  PERMIT - SIGNS
# 4                  PERMIT - SIGNS
#
# [5 rows x 126 columns]

# %% [markdown]
# ## Mobility Areas

# %%
df_community_areas = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/igwz-8jzy.json"
)

df_community_areas["label"] = df_community_areas["community"]
df_community_areas.head()
# Out:
#                                             the_geom perimeter area comarea  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...         0    0       0
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...         0    0       0
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...         0    0       0
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...         0    0       0
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...         0    0       0
#
#   comarea_id area_numbe        community area_num_1     shape_area  \
# 0          0         35          DOUGLAS         35  46004621.1581
# 1          0         36          OAKLAND         36  16913961.0408
# 2          0         37      FULLER PARK         37  19916704.8692
# 3          0         38  GRAND BOULEVARD         38  48492503.1554
# 4          0         39          KENWOOD         39  29071741.9283
#
#        shape_len            label
# 0  31027.0545098          DOUGLAS
# 1  19565.5061533          OAKLAND
# 2  25339.0897503      FULLER PARK
# 3  28196.8371573  GRAND BOULEVARD
# 4  23325.1679062          KENWOOD

# %%
# mark which community areas are mobility areas
mobility_areas = [
    "KENWOOD",
    "LINCOLN SQUARE",
    "HYDE PARK",
    "ROGERS PARK",
    "JEFFERSON PARK",
    "FOREST GLEN",
    "NORTH PARK",
    "ALBANY PARK",
    "PORTAGE PARK",
    "IRVING PARK",
    "DUNNING",
    "MONTCLARE",
    "BELMONT CRAGIN",
    "WEST RIDGE",
    "HERMOSA",
    "AVONDALE",
    "LOGAN SQUARE",
    "WEST TOWN",
    "NEAR WEST SIDE",
    "UPTOWN",
    "NEAR SOUTH SIDE",
    "ARMOUR SQUARE",
    "NORWOOD PARK",
    "NEAR NORTH SIDE",
    "LOOP",
    "LAKE VIEW",
    "NORTH CENTER",
    "EAST SIDE",
    "HEGEWISCH",
    "GARFIELD RIDGE",
    "ARCHER HEIGHTS",
    "BRIDGEPORT",
    "WEST ELSDON",
    "CLEARING",
    "WEST LAWN",
    "LINCOLN PARK",
    "ASHBURN",
    "BEVERLY",
    "MOUNT GREENWOOD",
    "MORGAN PARK",
    "OHARE",
    "EDGEWATER",
    "EDISON PARK",
]

# subset to mobility areas
df_mobility_areas = df_community_areas.loc[
    df_community_areas.community.isin(mobility_areas)
]

# %%
# create geometry variable for the shapes
df_mobility_areas["geometry"] = df_mobility_areas["the_geom"].apply(
    lambda x: Polygon(x["coordinates"][0][0])
)
gdf_mobility_areas = gpd.GeoDataFrame(
    data=df_mobility_areas, crs="EPSG:4326", geometry="geometry"
)

# %% [markdown]
# ## ADU Areas

# %%
df_ADU = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/ttjb-ayff.json"
)

df_ADU["label"] = df_ADU["area"]
df_ADU.head()
# Out:
#                                             the_geom objectid       area  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        1       West
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        3      North
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        5  Southeast
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        8  Northwest
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       11      South
#
#       shape_leng     shape_area      label
# 0  51421.0696119   139856090.07       West
# 1  78723.3692912  291136399.974      North
# 2  91576.4719351  321419159.095  Southeast
# 3  122124.562254  180457542.639  Northwest
# 4  146010.910711  476944013.591      South

# %%
# create geometry variable for the shapes
df_ADU["geometry"] = df_ADU["the_geom"].apply(lambda x: Polygon(x["coordinates"][0][0]))
gdf_ADU = gpd.GeoDataFrame(data=df_ADU, crs="EPSG:4326", geometry="geometry")

# %%
# without a .zip shapefile, we have to convert into a geoseries and project the points
# df_ADU = gpd.read_file(os.path.join(SHAPE_FILES, "Additional_Dwelling_Unit_Areas.tsv"))
# df_ADU['geometry'] = gpd.GeoSeries.from_wkt(df_ADU['the_geom'])
# df_ADU['geometry'].crs = "EPSG:4326"

# %% [markdown]
# ## Zoning

# %%
# get zoning spatial data
df_zoning = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/dj47-wfun.json"
)

df_zoning["label"] = df_zoning["zone_class"]
df_zoning.head()
# Out:
#                                             the_geom case_numbe zoning_id  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          0      2488
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          0      4088
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          0      4745
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          0      4086
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          0      5525
#
#   zone_type zone_class edit_statu                create_dat  \
# 0         2       C2-3     ACTIVE  2002-08-14T00:00:00.000Z
# 1         1       B1-1     ACTIVE  2002-08-29T00:00:00.000Z
# 2         2       C2-2     ACTIVE  2002-09-05T00:00:00.000Z
# 3         3       M2-3     ACTIVE  2002-08-29T00:00:00.000Z
# 4         5     PD 416     ACTIVE  2002-09-12T00:00:00.000Z
#
#                   edit_date pd_num               ordinance_1     shape_area  \
# 0  1899-11-30T00:00:00.000Z      0  1899-11-30T00:00:00.000Z  41101.3463588
# 1  1899-11-30T00:00:00.000Z      0  1899-11-30T00:00:00.000Z  3981.02012211
# 2  1899-11-30T00:00:00.000Z      0  1899-11-30T00:00:00.000Z  21286.1923599
# 3  1899-11-30T00:00:00.000Z      0  1899-11-30T00:00:00.000Z  489097.720164
# 4  1899-11-30T00:00:00.000Z    416  1899-11-30T00:00:00.000Z  350813.081204
#
#        shape_len pd_prefix edit_uid comments ordinance case_type create_uid  \
# 0  817.327179297       NaN      NaN      NaN       NaN       NaN        NaN
# 1  380.062184507       NaN      NaN      NaN       NaN       NaN        NaN
# 2  590.945627594       NaN      NaN      NaN       NaN       NaN        NaN
# 3   2889.9502873       NaN      NaN      NaN       NaN       NaN        NaN
# 4  3526.80670883         I      NaN      NaN       NaN       NaN        NaN
#
#     label
# 0    C2-3
# 1    B1-1
# 2    C2-2
# 3    M2-3
# 4  PD 416

# %%
df_zoning["geometry"] = df_zoning["the_geom"].apply(
    lambda x: Polygon(x["coordinates"][0][0])
)
gdf_zoning = gpd.GeoDataFrame(data=df_zoning, crs="EPSG:4326", geometry="geometry")

# %% [markdown]
# ## Bike Routes

# %%
df_bike_routes = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/hvv9-38ut.json"
)

df_bike_routes["label"] = df_bike_routes["st_name"]
df_bike_routes.head()
# Out:
#                                             the_geom         street  \
# 0  {'type': 'MultiLineString', 'coordinates': [[[...   MARQUETTE RD
# 1  {'type': 'MultiLineString', 'coordinates': [[[...   MARQUETTE RD
# 2  {'type': 'MultiLineString', 'coordinates': [[[...        18TH ST
# 3  {'type': 'MultiLineString', 'coordinates': [[[...  LAKE SHORE DR
# 4  {'type': 'MultiLineString', 'coordinates': [[[...       WELLS ST
#
#       st_name oneway_dir            f_street          t_street  \
# 0   MARQUETTE          -  S CENTRAL PARK AVE      S KEDZIE AVE
# 1   MARQUETTE          -        S KEDZIE AVE  S SACRAMENTO AVE
# 2        18TH        NaN         S DAMEN AVE       S LOOMIS ST
# 3  LAKE SHORE        NaN           E 81ST ST         E 87TH ST
# 4       WELLS          S      W VAN BUREN ST       W ARCADE PL
#
#            displayrou      mi_ctrline br_oneway br_ow_dir contraflow  \
# 0  BUFFERED BIKE LANE  0.495169733402         N         -          -
# 1         SHARED-LANE  0.252403055895         N         -          -
# 2           BIKE LANE  0.757320648958         N       NaN        NaN
# 3  BUFFERED BIKE LANE  0.754309006935         N       NaN        NaN
# 4         SHARED-LANE  0.306834750149         Y         S          N
#
#         label
# 0   MARQUETTE
# 1   MARQUETTE
# 2        18TH
# 3  LAKE SHORE
# 4       WELLS

# %%
# create geometry variable for the lines
df_bike_routes["geometry"] = df_bike_routes["the_geom"].apply(
    lambda x: LineString(x["coordinates"][0])
)
gdf_bike_routes = gpd.GeoDataFrame(
    data=df_bike_routes, crs="EPSG:4326", geometry="geometry"
)

# %% [markdown]
# ## Wards

# %%
df_wards = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/k9yb-bpqx.json"
)

df_wards["label"] = df_wards["ward"]
df_wards.head()
# Out:
#                                             the_geom ward     shape_leng  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...   12  93073.3408379
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...   16  97901.3238332
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...   15  82183.6948197
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...   20  90105.1956185
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...   49  38122.6928259
#
#       shape_area label
# 0  116096507.849    12
# 1  103143638.546    16
# 2   65588297.917    15
# 3   137290356.97    20
# 4  49733459.1385    49

# %%
df_wards["geometry"] = df_wards["the_geom"].apply(
    lambda x: Polygon(x["coordinates"][0][0])
)
gdf_wards = gpd.GeoDataFrame(data=df_wards, crs="EPSG:4326", geometry="geometry")

# %% [markdown]
# ## Neighborhoods

# %%
df_neighborhoods = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/y6yq-dbs2.json"
)

df_neighborhoods["label"] = df_neighborhoods["pri_neigh"]
df_neighborhoods.head()
# Out:
#                                             the_geom           pri_neigh  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...     Grand Boulevard
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        Printers Row
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       United Center
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...  Sheffield & DePaul
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       Humboldt Park
#
#             sec_neigh     shape_area     shape_len               label
# 0         BRONZEVILLE  48492503.1554  28196.837157     Grand Boulevard
# 1        PRINTERS ROW  2162137.97139   6864.247156        Printers Row
# 2       UNITED CENTER  32520512.7053  23101.363745       United Center
# 3  SHEFFIELD & DEPAUL  10482592.2987  13227.049745  Sheffield & DePaul
# 4       HUMBOLDT PARK  125010425.593  46126.751351       Humboldt Park

# %%
df_neighborhoods["geometry"] = df_neighborhoods["the_geom"].apply(
    lambda x: Polygon(x["coordinates"][0][0])
)
gdf_neighborhoods = gpd.GeoDataFrame(
    data=df_neighborhoods, crs="EPSG:4326", geometry="geometry"
)

# %% [markdown]
# ## Enterprise Zones

# %%
df_enterprise_zones = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/bwpt-y235.json"
)

df_enterprise_zones["label"] = df_enterprise_zones["name"]
df_enterprise_zones.head()
# Out:
#   display_co                                           the_geom objectid  \
# 0          1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        1
# 1          0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        3
# 2          0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        4
# 3          0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        5
# 4          6  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        6
#
#   enterprise name     shape_leng     shape_area label
# 0          5    5  166021.685716  235940637.947     5
# 1          2    2  232181.868554  337162988.056     2
# 2          4    4  265182.045484  250430390.712     4
# 3          3    3  342171.797656  446806134.969     3
# 4          6    6  334404.043467  327062437.241     6

# %%
df_enterprise_zones["geometry"] = df_enterprise_zones["the_geom"].apply(
    lambda x: Polygon(x["coordinates"][0][0])
)
gdf_enterprise_zones = gpd.GeoDataFrame(
    data=df_enterprise_zones, crs="EPSG:4326", geometry="geometry"
)

# %% [markdown]
# ## Public High Schools

# %%
df_hs = get_SODA_data(
    api_endpoint="https://data.cityofchicago.org/resource/juf9-y87b.json"
)

df_hs["label"] = df_hs["school_nm"]
df_hs.head()
# Out:
#   school_id       school_nm                              school_add  \
# 0    609691  NORTH-GRAND HS  4338 W WABANSIA AVE  CHICAGO, IL 60639
# 1    609695     AMUNDSEN HS     5110 N DAMEN AVE  CHICAGO, IL 60625
# 2    609698        BOGAN HS       3939 W 79TH ST  CHICAGO, IL 60652
# 3    610323        BOWEN HS       2710 E 89TH ST  CHICAGO, IL 60617
# 4    610518   AUSTIN CCA HS        231 N PINE AVE CHICAGO, IL 60644
#
#                                             the_geom grade_cat     boundarygr  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        HS  9, 10, 11, 12
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        HS  9, 10, 11, 12
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        HS  9, 10, 11, 12
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        HS  9, 10, 11, 12
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...        HS  9, 10, 11, 12
#
#                     sch_type     shape_leng     shape_area           label
# 0  District, non-alternative  21536.4574225  18818852.8467  NORTH-GRAND HS
# 1  District, non-alternative  42505.3602555  73276218.3437     AMUNDSEN HS
# 2  District, non-alternative  63913.7580959  204960361.339        BOGAN HS
# 3  District, non-alternative   13732.613646  11384287.2148        BOWEN HS
# 4  District, non-alternative  44154.4120323  67205615.8692   AUSTIN CCA HS

# %%
df_hs["geometry"] = df_hs["the_geom"].apply(lambda x: Polygon(x["coordinates"][0][0]))
gdf_hs = gpd.GeoDataFrame(data=df_hs, crs="EPSG:4326", geometry="geometry")

# %% [markdown]
# # Combine all data sources

# %%
sources_point_data = {
    "EV_chargers": df_EV_chargers,
    "farmers_market": df_farmers_market,
    "divvy": df_divvy,
    "L": df_L,
    "licenses": df_licenses,
    "current_licenses": df_current_licenses,
    "liquor": df_liquor,
    "landmarks": df_landmarks,
    "park_art": df_park_art,
    "murals": df_murals,
    "grocery": df_grocery,
    "permits": df_permits,
    "hospitals": df_hospitals,
    "metra": df_metra,
}

# %%
df_location_combined = pd.DataFrame(
    columns=["source", "label", "latitude", "longitude"]
)

for name, df in sources_point_data.items():
    df_location = df[["label", "latitude", "longitude"]]
    df_location["source"] = name
    df_location_combined = pd.concat([df_location_combined, df_location])

df_location_combined.reset_index(drop=True, inplace=True)

# fix data types
df_location_combined.latitude = df_location_combined.latitude.astype("float")
df_location_combined.longitude = df_location_combined.longitude.astype("float")

# %%
# df_location_combined.latitude.plot(kind='kde')

# %%
# df_location_combined.longitude.plot(kind='kde')

# %%
sources_shape_data = {
    "mobility_areas": gdf_mobility_areas,
    "ADU": gdf_ADU,
    "zoning": gdf_zoning,
    "bike_routes": df_bike_routes,
    "ward": gdf_wards,
    "neighborhood": gdf_neighborhoods,
    "enterprise_zone": df_enterprise_zones,
    "high_schools": gdf_hs,
}

# %%
df_shape_data_combined = pd.DataFrame(columns=["source", "label", "geometry"])

for name, df in sources_shape_data.items():
    df_shape_data = df[["label", "geometry"]]
    df_shape_data["source"] = name
    df_shape_data_combined = pd.concat([df_shape_data_combined, df_shape_data])


df_shape_data_combined.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\Beau\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\array.py:1406: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as WGS 84 (the single non-null crs provided).
#   warnings.warn(

# %%
# make column names upper case
df_location_combined.columns = [col.upper() for col in df_location_combined.columns]
df_shape_data_combined.columns = [col.upper() for col in df_shape_data_combined.columns]

# %%
# write data
df_location_combined.to_pickle(os.path.join(CLEANED, "whats_nearby_location_data.pkl"))
df_shape_data_combined.to_pickle(os.path.join(CLEANED, "whats_nearby_shape_data.pkl"))

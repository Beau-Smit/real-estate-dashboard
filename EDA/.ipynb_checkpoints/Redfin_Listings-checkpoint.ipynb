# %%
import pandas as pd
import numpy as np
import os
import folium
import map_functions

# %%
ROOT = "C:/Users/Beau/Documents/GitHub/RealEstate"
RAW = os.path.join(ROOT, "data", "raw")
SERIALIZED = os.path.join(ROOT, "data", "serialized")
CLEANED = os.path.join(ROOT, "data", "processed")

# %%
# serialize data
# path = os.path.join(RAW, "redfin_homes_sold_1_year.csv")
# df = pd.read_csv(path)
# df.to_pickle(os.path.join(SERIALIZED, "redfin_homes_sold_1_year.pkl"))

# %%
df = pd.read_pickle(os.path.join(SERIALIZED, "redfin_homes_sold_1_year.pkl"))

# %%
# filter irrelevant rows
df = df.loc[df.CITY == "Chicago"]
df = df.loc[df["PROPERTY TYPE"].isin(["Single Family Residential", "Condo/Co-op", "Multi-Family (2-4 Unit)", "Townhouse"])]

# %%
# drop unnecessary columns
df.drop([
    "SALE TYPE",
    "SOLD DATE",
    "CITY",
    "STATE OR PROVINCE",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "STATUS",
    "SOURCE",
    "FAVORITE",
    "INTERESTED"
], axis=1, inplace=True)

# %%
# fix row with misinformation
idx = df.loc[df["$/SQUARE FEET"] > 3000].index[0]
df.loc[idx, "$/SQUARE FEET"] = 600.0
df.loc[idx, "$/SQUARE FEET"] = 305.0

# %%
print(df["$/SQUARE FEET"].median())
df["$/SQUARE FEET"].plot(kind="hist")
# Out:
# 211.0
# <AxesSubplot:ylabel='Frequency'>

# %%
# Create a Map instance for Chicago
m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)

for idx, row in df.iterrows():
    map_functions.add_map_marker(m, row.LATITUDE, row.LONGITUDE, row["PRICE"])
    # map_functions.add_map_circle(row.LATITUDE, row.LONGITUDE)

# Change the map style
# m.add_tile_layer(tiles='Stamen Toner', name='Stamen Toner')

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac1338e4d45ea11d3a9ada6563f40d1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac1338e4d45ea11d3a9ada6563f40d1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac1338e4d45ea11d3a9ada6563f40d1f = L.map(
#                 &quot;map_ac1338e4d45ea11d3a9ada6563f40d1f&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c6e117df0707a7874502d3d57cfd673 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac1338e4d45ea11d3a9ada6563f40d1f);
#
#
#             var marker_bcade9544ef898c0d974192cd9c17c61 = L.marker(
#                 [41.9278591, -87.7026447],
#                 {}
#             ).addTo(map_ac1338e4d45ea11d3a9ada6563f40d1f);
#
#
#             var icon_08f95f6175f1bdca3ff26a2b50337937 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bcade9544ef898c0d974192cd9c17c61.setIcon(icon_08f95f6175f1bdca3ff26a2b50337937);
#
#
#         var popup_cf54ace46ce3b9c594a54940221e229f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba5993fb2947cda82165d4a2fad27f46 = $(`&lt;div id=&quot;html_ba5993fb2947cda82165d4a2fad27f46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;312900&lt;/div&gt;`)[0];
#                 popup_cf54ace46ce3b9c594a54940221e229f.setContent(html_ba5993fb2947cda82165d4a2fad27f46);
#
#
#
#         marker_bcade9544ef898c0d974192cd9c17c61.bindPopup(popup_cf54ace46ce3b9c594a54940221e229f)
#         ;
#
#
#
#
#             var marker_e878ddf2a2d4d8ac6e22cd906de82d80 = L.marker(
#                 [41.8473395, -87.6199353],
#                 {}
#             ).addTo(map_ac1338e4d45ea11d3a9ada6563f40d1f);
#
#
#             var icon_3f69167542e5fd25ef449c3576219e9d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e878ddf2a2d4d8ac6e22cd906de82d80.setIcon(icon_3f69167542e5fd25ef449c3576219e9d);
#
#
#         var popup_05d321a0d72f2a2d367d8f76ee14d406 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bbe29bc06fa3bf980b67d7b5d25a0f8 = $(`&lt;div id=&quot;html_5bbe29bc06fa3bf980b67d7b5d25a0f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;290000&lt;/div&gt;`)[0];
#                 popup_05d321a0d72f2a2d367d8f76ee14d406.setContent(html_5bbe29bc06fa3bf980b67d7b5d25a0f8);
#
#
#
#         marker_e878ddf2a2d4d8ac6e22cd906de82d80.bindPopup(popup_05d321a0d72f2a2d367d8f76ee14d406)
#         ;
#
#
#
#
#             var marker_b3b565d352ec40fb831e686407dee705 = L.marker(
#                 [41.7516549, -87.6098213],
#                 {}
#             ).addTo(map_ac1338e4d45ea11d3a9ada6563f40d1f);
#
#
#             var icon_4dd266f8ecd99c655e673187c43827a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b3b565d352ec40fb831e686407dee705.setIcon(icon_4dd266f8ecd99c655e673187c43827a3);
#
#
#         var popup_5e85010ad4b20b51ae65251c1dc76f71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6de64f17346c06e3647a4b1d037dbeb2 = $(`&lt;div id=&quot;html_6de64f17346c06e3647a4b1d037dbeb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;225000&lt;/div&gt;`)[0];
#                 popup_5e85010ad4b20b51ae65251c1dc76f71.setContent(html_6de64f17346c06e3647a4b1d037dbeb2);
#
#
#
#         marker_b3b565d352ec40fb831e686407dee705.bindPopup(popup_5e85010ad4b20b51ae65251c1dc76f71)
#         ;
#
#
#
#
#             var marker_e7bcd9ba6f95a38fed3a5f8b363f4c06 = L.marker(
#                 [41.876095, -87.6512602],
#                 {}
#             ).addTo(map_ac1338e4d45ea11d3a9ada6563f40d1f);
#
#
#             var icon_745b824a6d2306a843053fff977a803c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColo

# %%
df.to_pickle(os.path.join(CLEANED, "Redfin_Listings.pkl"))

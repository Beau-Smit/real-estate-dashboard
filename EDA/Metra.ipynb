# %%
import pandas as pd
import os
import folium
import map_functions

# %%
ROOT = "C:/Users/Beau/Documents/GitHub/RealEstate"
RAW = os.path.join(ROOT, "data", "raw")
SERIALIZED = os.path.join(ROOT, "data", "serialized")
CLEANED = os.path.join(ROOT, "data", "processed")

# %%
# serialize data
# path = os.path.join(RAW, "Metra_Stations.csv")
# df = pd.read_csv(path)
# df.to_pickle(os.path.join(SERIALIZED, "Metra_Stations.pkl"))

# %%
df = pd.read_pickle(os.path.join(SERIALIZED, "Metra_Stations.pkl"))

# %%
df.head()
# Out:
#      STATION_NAME   LATITUDE  LONGITUDE
# 0   Union Station  41.878683 -87.638892
# 1  Western Avenue  41.889180 -87.688161
# 2           Healy  41.924750 -87.727983
# 3        Grayland  41.948852 -87.740302
# 4         Mayfair  41.960163 -87.746298

# %%
# Create a Map instance for Chicago
m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)

for idx, row in df.iterrows():
    map_functions.add_map_marker(m, row.LATITUDE, row.LONGITUDE, row["STATION_NAME"])
    # map_functions.add_map_circle(row.Latitude, row.Longitude)

# Change the map style
# m.add_tile_layer(tiles='Stamen Toner', name='Stamen Toner')

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6184e6fd8ac504728b5968932d887543 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6184e6fd8ac504728b5968932d887543&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6184e6fd8ac504728b5968932d887543 = L.map(
#                 &quot;map_6184e6fd8ac504728b5968932d887543&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07a200928b2ef18958e75a10336fc2ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6184e6fd8ac504728b5968932d887543);
#
#
#             var marker_369f22ac6bd922be67d01869b5bf8eb9 = L.marker(
#                 [41.87868309, -87.63889217],
#                 {}
#             ).addTo(map_6184e6fd8ac504728b5968932d887543);
#
#
#             var icon_a61f3014f7d5d47a1fc3082d401734b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_369f22ac6bd922be67d01869b5bf8eb9.setIcon(icon_a61f3014f7d5d47a1fc3082d401734b9);
#
#
#         var popup_efa010df42d7ec8b8c4ccbe2432cbf8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ef7d43f6e6f6bf3bf22fa2e72f655ae = $(`&lt;div id=&quot;html_0ef7d43f6e6f6bf3bf22fa2e72f655ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Union Station&lt;/div&gt;`)[0];
#                 popup_efa010df42d7ec8b8c4ccbe2432cbf8d.setContent(html_0ef7d43f6e6f6bf3bf22fa2e72f655ae);
#
#
#
#         marker_369f22ac6bd922be67d01869b5bf8eb9.bindPopup(popup_efa010df42d7ec8b8c4ccbe2432cbf8d)
#         ;
#
#
#
#
#             var marker_a04d6d05b5811074243ab7532ff1eab0 = L.marker(
#                 [41.88918032, -87.68816096],
#                 {}
#             ).addTo(map_6184e6fd8ac504728b5968932d887543);
#
#
#             var icon_14ea05739fb02a4002aebd294b20f601 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a04d6d05b5811074243ab7532ff1eab0.setIcon(icon_14ea05739fb02a4002aebd294b20f601);
#
#
#         var popup_623345cb2fb754b0529e0909e56b3950 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b17484d820fcfeffd5b73e32d0340cde = $(`&lt;div id=&quot;html_b17484d820fcfeffd5b73e32d0340cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Western Avenue&lt;/div&gt;`)[0];
#                 popup_623345cb2fb754b0529e0909e56b3950.setContent(html_b17484d820fcfeffd5b73e32d0340cde);
#
#
#
#         marker_a04d6d05b5811074243ab7532ff1eab0.bindPopup(popup_623345cb2fb754b0529e0909e56b3950)
#         ;
#
#
#
#
#             var marker_db1c56671fe1db634ffc7270b711bb37 = L.marker(
#                 [41.92475007, -87.7279829],
#                 {}
#             ).addTo(map_6184e6fd8ac504728b5968932d887543);
#
#
#             var icon_8eecb7eba3f9491444c115ac2fc10809 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db1c56671fe1db634ffc7270b711bb37.setIcon(icon_8eecb7eba3f9491444c115ac2fc10809);
#
#
#         var popup_a62cf5894b1b593f4d96448cb2a9d76c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f232904d1508bf19f1553ef317f0271 = $(`&lt;div id=&quot;html_6f232904d1508bf19f1553ef317f0271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Healy&lt;/div&gt;`)[0];
#                 popup_a62cf5894b1b593f4d96448cb2a9d76c.setContent(html_6f232904d1508bf19f1553ef317f0271);
#
#
#
#         marker_db1c56671fe1db634ffc7270b711bb37.bindPopup(popup_a62cf5894b1b593f4d96448cb2a9d76c)
#         ;
#
#
#
#
#             var marker_e77d3bd66bc2a9c388e2846e625ebe4d = L.marker(
#                 [41.9488516, -87.74030203],
#                 {}
#             ).addTo(map_6184e6fd8ac504728b5968932d887543);
#
#
#             var icon_40014c7cac7ee37e198b280a24e46f6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot

# %%
df.to_pickle(os.path.join(CLEANED, "Metra_Stations.pkl"))
